# %%
import pandas as pd

pdfs = pd.read_csv("./src/corpus_pdfs_clean.csv")

# %%
pdfs.isna().sum()
# Out:
# file_name          0
# file_path          0
# page_label         0
# texte              0
# titre              0
# auteur            89
# date               0
# description       89
# nb_pages_total    89
# longueur           0
# dtype: int64

# %%
pdfs.head()
# Out:
#      file_name                                          file_path  page_label  \
# 0  2024_22.pdf  C:\Users\Apprenant\Desktop\Simplon\Dev IA\lear...         491
# 1  2024_22.pdf  C:\Users\Apprenant\Desktop\Simplon\Dev IA\lear...         492
# 2  2024_22.pdf  C:\Users\Apprenant\Desktop\Simplon\Dev IA\lear...         493
# 3  2024_22.pdf  C:\Users\Apprenant\Desktop\Simplon\Dev IA\lear...         494
# 4  2024_22.pdf  C:\Users\Apprenant\Desktop\Simplon\Dev IA\lear...         495
#
#                                                texte    titre  auteur  \
# 0  N° 22 | 12 novembre 2024\nBEH 22 | 12 novembre...  2024_22     NaN
# 1  492 | 12 novembre 2024 | BEH 22\nARTICLE // Ar...  2024_22     NaN
# 2  BEH 22 | 12 novembre 2024 | 493\nIntroduction\...  2024_22     NaN
# 3  494 | 12 novembre 2024 | BEH 22\net des  tenda...  2024_22     NaN
# 4  BEH 22 | 12 novembre 2024 | 495\ndes  années, ...  2024_22     NaN
#
#          date  description  nb_pages_total  longueur
# ...
